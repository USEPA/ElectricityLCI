# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from electricitylci import get_generation_process_df, get_generation_mix_process_df
from electricitylci.consumption_mix import check_trading_normalized, trading_mix_fuels
from electricitylci.globals import data_dir

from os.path import join
# Out:
# Select a model number to use:
# 	1: ELCI_2
# 	2: ELCI_1
# 	3: ELCI_3
# 	4: ELCI_5
#  2
# Model ELCI_1 selected.

# %% [markdown]
# ## Test data

# %%
regions = [x for x in 'ABCD']

trade = {
    'A': [1, 0, 0, 0],
    'B': [0, .5, .25, .25],
    'C': [0, .1, .9, 0],
    'D': [0, 0, .5, .5]
}
trade_df = pd.DataFrame(data=trade, index=regions)

fuels = ['gas', 'wind']

gen_df = pd.DataFrame(
    index = pd.MultiIndex.from_product([regions, fuels],
                                       names=['Subregion', 'FuelCategory']),
    columns = ['Generation_Ratio'],
    data = [1, 0, 0, 1, .5, .5, .1, .9]
).reset_index()

# %%
gen_df
# Out:
#   Subregion FuelCategory  Generation_Ratio
# 0         A          gas               1.0
# 1         A         wind               0.0
# 2         B          gas               0.0
# 3         B         wind               1.0
# 4         C          gas               0.5
# 5         C         wind               0.5
# 6         D          gas               0.1
# 7         D         wind               0.9

# %%
trade_df
# Out:
#    A     B    C    D
# A  1  0.00  0.0  0.0
# B  0  0.50  0.1  0.0
# C  0  0.25  0.9  0.5
# D  0  0.25  0.0  0.5

# %%
print(trading_mix_fuels(gen_mix=gen_df, trading_matrix=trade_df))
# Out:
#    Subregion from_region FuelCategory  trading_gen_ratio
# 0          A           A          gas              1.000
# 1          B           B         wind              0.500
# 2          B           C          gas              0.125
# 3          B           C         wind              0.125
# 4          B           D          gas              0.025
# 5          B           D         wind              0.225
# 6          C           B         wind              0.100
# 7          C           C          gas              0.450
# 8          C           C         wind              0.450
# 9          D           C          gas              0.250
# 10         D           C         wind              0.250
# 11         D           D          gas              0.050
# 12         D           D         wind              0.450

# %%
trading_mix_fuels(gen_mix=gen_df, trading_matrix=trade_df)
# Out:
#    Subregion from_region FuelCategory  trading_gen_ratio
# 0          A           A          gas              1.000
# 1          B           B         wind              0.500
# 2          B           C          gas              0.125
# 3          B           C         wind              0.125
# 4          B           D          gas              0.025
# 5          B           D         wind              0.225
# 6          C           B         wind              0.100
# 7          C           C          gas              0.450
# 8          C           C         wind              0.450
# 9          D           C          gas              0.250
# 10         D           C         wind              0.250
# 11         D           D          gas              0.050
# 12         D           D         wind              0.450

# %% [markdown]
# ## BA name/code match

# %%
path = join(data_dir, 'BA code match.csv')
ba_match = pd.read_csv(path)

# %%
ba_match.set_index('ba_name', inplace=True)

# %% [markdown]
# ## Trading data

# %%
trading_actual = pd.read_csv('trading_matrix_actual_region.csv', index_col=0)

# %%
trading_actual = pd.read_csv('trading_matrix_actual_BA.csv', index_col=1)
trading_actual = trading_actual.loc[:, 'AEC':]

# %%
trading_actual.tail()
# Out:
#             AEC         AECI           AVA         AZPS         BANC  BCHA  \
# Source BAA
# WALC        0.0     0.000004      0.000000   205.748501     0.000000   0.0
# WAUE        0.0     0.000000      0.000000     0.000000     0.000000   0.0
# WAUW        0.0  1919.154157      0.000000  8269.596330     0.000000   0.0
# WWA         0.0    44.341214  20432.689099  1104.702939  9837.652922   0.0
# YAD         0.0     0.000000      0.000000     0.000000     0.000000   0.0
#
#                     BPAT  CHPD          CISO          CPLE   ...     \
# Source BAA                                                   ...
# WALC            0.000000   0.0  2.299981e+06  2.566513e-11   ...
# WAUE            0.000000   0.0  0.000000e+00  0.000000e+00   ...
# WAUW            0.000000   0.0  5.070989e+03  1.175174e-02   ...
# WWA         94279.632738   0.0  2.692337e+04  2.715189e-04   ...
# YAD             0.000000   0.0  0.000000e+00  1.032469e+04   ...
#
#                     TEPC          TIDC         TPWR           TVA  \
# Source BAA
# WALC        1.389344e+06  10012.137492     0.000000  5.329872e-07
# WAUE        0.000000e+00      0.000000     0.000000  0.000000e+00
# WAUW        2.258085e+03     22.074721     0.000000  2.440482e+02
# WWA         1.684637e+02    206.585958  2698.554571  5.638625e+00
# YAD         0.000000e+00      0.000000     0.000000  6.771262e+00
#
#                      WACM          WALC  WAUE           WAUW    WWA      YAD
# Source BAA
# WALC             0.792476  8.756409e+06   0.0       0.000000    0.0      0.0
# WAUE             0.000000  0.000000e+00   0.0       0.000000    0.0      0.0
# WAUW        161094.415578  9.123140e+03   0.0  690867.500000    0.0      0.0
# WWA           3725.533214  4.188278e+02   0.0   15962.183553 -523.0      0.0
# YAD              0.000000  0.000000e+00   0.0       0.000000    0.0  49449.5
#
# [5 rows x 74 columns]

# %%
pd.Series(np.diag(trading_actual), index=[trading_actual.index, trading_actual.columns])
# Out:
# Source BAA
# AEC         AEC     4.544007e+06
# AECI        AECI    1.958502e+07
# AVA         AVA     9.846925e+06
# AZPS        AZPS    3.127218e+07
# BANC        BANC    1.729542e+07
# BCHA        BCHA    0.000000e+00
# BPAT        BPAT    6.615449e+07
# CHPD        CHPD    3.286178e+06
# CISO        CISO    2.061889e+08
# CPLE        CPLE    6.083340e+07
# CPLW        CPLW    4.945908e+06
# DEAA        DEAA    0.000000e+00
# DOPD        DOPD    1.174210e+06
# DUK         DUK     1.045663e+08
# EEI         EEI     3.530287e+04
# EPE         EPE     8.333488e+06
# ERCO        ERCO    3.482001e+08
# FMPP        FMPP    1.753042e+07
# FPC         FPC     5.298050e+07
# FPL         FPL     1.245266e+08
# GCPD        GCPD    4.746350e+06
# GRID        GRID    2.931000e+03
# GRIF        GRIF   -2.000000e+00
# GRIS        GRIS    0.000000e+00
# GRMA        GRMA    3.502000e+03
# GVL         GVL     2.059152e+06
# GWA         GWA    -9.025000e+02
# HGMA        HGMA   -5.000000e-01
# HQT         HQT     0.000000e+00
# HST         HST     5.175560e+05
#                         ...
# NYIS        NYIS    1.605775e+08
# OVEC        OVEC    1.500528e+06
# PACE        PACE    3.863770e+07
# PACW        PACW    2.990445e+07
# PGE         PGE     1.657539e+07
# PJM         PJM     8.088590e+08
# PNM         PNM     1.429991e+07
# PSCO        PSCO    4.316432e+07
# PSEI        PSEI    3.016259e+07
# SC          SC      2.449559e+07
# SCEG        SCEG    2.462808e+07
# SCL         SCL     9.711360e+06
# SEC         SEC     3.693809e+10
# SEPA        SEPA    5.311451e+04
# SOCO        SOCO    2.305242e+08
# SPA         SPA     6.430565e+05
# SRP         SRP     2.951190e+07
# SWPP        SWPP    2.572141e+08
# TAL         TAL     2.768406e+06
# TEC         TEC     2.153577e+07
# TEPC        TEPC    1.446956e+07
# TIDC        TIDC    2.608954e+06
# TPWR        TPWR    4.774664e+06
# TVA         TVA     1.602318e+08
# WACM        WACM    2.522839e+07
# WALC        WALC    8.756409e+06
# WAUE        WAUE    0.000000e+00
# WAUW        WAUW    6.908675e+05
# WWA         WWA    -5.230000e+02
# YAD         YAD     4.944950e+04
# Length: 74, dtype: float64

# %%
check_trading_normalized(trading_actual)

# %%
trading_actual.tail(5)
# Out:
#             AEC          AECI       AVA      AZPS      BANC  BCHA      BPAT  \
# Source BAA
# WALC        0.0  1.910153e-13  0.000000  0.000005  0.000000   NaN  0.000000
# WAUE        0.0  0.000000e+00  0.000000  0.000000  0.000000   NaN  0.000000
# WAUW        0.0  8.746351e-05  0.000000  0.000220  0.000000   NaN  0.000000
# WWA         0.0  2.020806e-06  0.001388  0.000029  0.000379   NaN  0.001138
# YAD         0.0  0.000000e+00  0.000000  0.000000  0.000000   NaN  0.000000
#
#             CHPD      CISO          CPLE ...       TEPC      TIDC      TPWR  \
# Source BAA                               ...
# WALC         0.0  0.008698  4.106204e-19 ...   0.057564  0.002506  0.000000
# WAUE         0.0  0.000000  0.000000e+00 ...   0.000000  0.000000  0.000000
# WAUW         0.0  0.000019  1.880180e-10 ...   0.000094  0.000006  0.000000
# WWA          0.0  0.000102  4.344072e-12 ...   0.000007  0.000052  0.000378
# YAD          0.0  0.000000  1.651864e-04 ...   0.000000  0.000000  0.000000
#
#                      TVA          WACM      WALC  WAUE      WAUW  WWA  YAD
# Source BAA
# WALC        3.088518e-15  2.939391e-08  0.559271   NaN  0.000000 -0.0  0.0
# WAUE        0.000000e+00  0.000000e+00  0.000000   NaN  0.000000 -0.0  0.0
# WAUW        1.414194e-06  5.975188e-03  0.000583   NaN  0.563311 -0.0  0.0
# WWA         3.267432e-08  1.381846e-04  0.000027   NaN  0.013015  1.0  0.0
# YAD         3.923765e-08  0.000000e+00  0.000000   NaN  0.000000 -0.0  1.0
#
# [5 rows x 74 columns]

# %%
trading_actual.iloc[:, 0]
# Out:
# Source_Region
# California                                     0.742308
# Carolinas                                      0.000000
# Central                                        0.000000
# Electric Reliability Council of Texas, Inc.    0.000000
# Florida                                        0.000000
# Mid-Atlantic                                   0.000000
# Midwest                                        0.000000
# New England ISO                                0.000000
# New York Independent System Operator           0.000000
# Northwest                                      0.141222
# Southeast                                      0.000000
# Southwest                                      0.116471
# Tennessee Valley Authority                     0.000000
# Name: California, dtype: float64

# %%
trading_norm = trading_actual.copy()

# %%
for col in trading_norm.columns:
    trading_norm[col] /= trading_norm[col].sum()

# %%
trading_norm.head()
# Out:
#                                              California     Carolinas  \
# Source_Region
# California                                     0.742308  7.693603e-15
# Carolinas                                      0.000000  9.566665e-01
# Central                                        0.000000  9.475246e-06
# Electric Reliability Council of Texas, Inc.    0.000000  1.838383e-09
# Florida                                        0.000000  0.000000e+00
#
#                                                   Central  \
# Source_Region
# California                                   1.517710e-09
# Carolinas                                    0.000000e+00
# Central                                      9.965565e-01
# Electric Reliability Council of Texas, Inc.  3.626562e-04
# Florida                                      0.000000e+00
#
#                                              Electric Reliability Council of Texas, Inc.  \
# Source_Region
# California                                                                           0.0
# Carolinas                                                                            0.0
# Central                                                                              0.0
# Electric Reliability Council of Texas, Inc.                                          1.0
# Florida                                                                              0.0
#
#                                                   Florida  Mid-Atlantic  \
# Source_Region
# California                                   4.759087e-18  1.043652e-14
# Carolinas                                    1.588492e-06  9.258602e-03
# Central                                      5.861171e-09  1.285335e-05
# Electric Reliability Council of Texas, Inc.  1.137182e-12  2.493801e-09
# Florida                                      9.997743e-01  0.000000e+00
#
#                                                   Midwest  New England ISO  \
# Source_Region
# California                                   1.023991e-11     1.539375e-17
# Carolinas                                    2.591913e-04     1.368911e-05
# Central                                      1.152934e-02     1.895855e-08
# Electric Reliability Council of Texas, Inc.  2.446822e-06     3.678331e-12
# Florida                                      0.000000e+00     0.000000e+00
#
#                                              New York Independent System Operator  \
# Source_Region
# California                                                           5.288244e-16
# Carolinas                                                            4.702644e-04
# Central                                                              6.512867e-07
# Electric Reliability Council of Texas, Inc.                          1.263624e-10
# Florida                                                              0.000000e+00
#
#                                              Northwest     Southeast  \
# Source_Region
# California                                    0.001599  2.068744e-14
# Carolinas                                     0.000000  6.945982e-03
# Central                                       0.000000  2.547812e-05
# Electric Reliability Council of Texas, Inc.   0.000000  4.943255e-09
# Florida                                       0.000000  0.000000e+00
#
#                                              Southwest  \
# Source_Region
# California                                    0.001834
# Carolinas                                     0.000000
# Central                                       0.000000
# Electric Reliability Council of Texas, Inc.   0.000000
# Florida                                       0.000000
#
#                                              Tennessee Valley Authority
# Source_Region
# California                                                 1.290240e-12
# Carolinas                                                  1.701044e-05
# Central                                                    1.589027e-03
# Electric Reliability Council of Texas, Inc.                3.083023e-07
# Florida                                                    0.000000e+00

# %%
trading_norm.sum(axis='rows').sum() == 13
# Out:
# True

# %% [markdown]
# ## Gen mix data

# %%
gen_mix = get_generation_mix_process_df(regions='BA')
gen_mix['Subregion'] = gen_mix['Subregion'].map(ba_match['ba_code'])
# Out:
# Actual generation data is used when replacing eGRID
# Loading 2017 EIA-923 data from csv file
# Loading 2017 EIA-860 plant data from csv file
# Loading 2017 EIA-923 data from csv file
# Loading 2017 EIA-860 plant data from csv file

# %%
gen_mix.columns
# Out:
# Index(['Subregion', 'FuelCategory', 'Electricity', 'Generation_Ratio'], dtype='object')

# %%
gen_mix.Subregion.unique()
# Out:
# array(['California', 'Carolinas', 'Central',
#        'Electric Reliability Council of Texas, Inc.', 'Florida',
#        'Mid-Atlantic', 'Midwest', 'New England ISO',
#        'New York Independent System Operator', 'Northwest', 'Southeast',
#        'Southwest', 'Tennessee Valley Authority'], dtype=object)

# %%
gen_mix.sample(5)
# Out:
#                                              Subregion FuelCategory  \
# 295                  Southwestern Power Administration          OIL
# 22                     Bonneville Power Administration          GAS
# 23                     Bonneville Power Administration   GEOTHERMAL
# 324  Western Area Power Administration - Rocky Moun...          GAS
# 325  Western Area Power Administration - Rocky Moun...        HYDRO
#
#      Electricity  Generation_Ratio
# 295       855.54          0.000118
# 22    8484460.00          0.072965
# 23      84436.00          0.000726
# 324   3416746.94          0.077913
# 325   1873242.00          0.042716

# %%
gen_mix.sample(5)
# Out:
#     Subregion FuelCategory   Electricity  Generation_Ratio
# 252       NaN        SOLAR  7.784930e+05          0.011712
# 51        NaN          GAS  5.405380e+05          0.901196
# 198       NaN   GEOTHERMAL  1.567000e+03          0.000153
# 5        AZPS         WIND  3.839280e+05          0.024148
# 158      NYIS        HYDRO  3.013397e+07          0.230043

# %%
len(gen_mix.Subregion.unique())
# Out:
# 51

# %%
trading_actual.shape
# Out:
# (74, 75)

# %%
gen_mix.dropna()

# %%
set(gen_mix.Subregion.dropna().unique()).issubset(set(trading_actual.index))
# Out:
# True

# %%
set(gen_mix.Subregion.unique()) - set(trading_actual.index)
# Out:
# {nan}

# %%
# %%time
results = trading_mix_fuels(gen_mix, trading_actual)
# Out:
# CPU times: user 20min 32s, sys: 12.4 s, total: 20min 44s
# Wall time: 21min 46s

# %%
gen_mix.loc[gen_mix.Subregion == 'California', :]
# Out:
#     Subregion FuelCategory   Electricity  Generation_Ratio
# 0  California      BIOMASS  5.102532e+06          0.025792
# 1  California          GAS  8.598807e+07          0.434641
# 2  California   GEOTHERMAL  1.197144e+07          0.060512
# 3  California        HYDRO  3.530088e+07          0.178434
# 4  California      NUCLEAR  1.790108e+07          0.090484
# 5  California         OFSL  6.652600e+04          0.000336
# 6  California          OIL  3.140752e+04          0.000159
# 7  California         OTHF  5.376168e+05          0.002717
# 8  California        SOLAR  2.749795e+07          0.138993
# 9  California         WIND  1.343936e+07          0.067932

# %%
set(gen_mix.Subregion.unique()) == set(trading_norm.index)
# Out:
# True

# %%
list(trading_norm.loc[trading_norm['California'] > 0, 'California'].iteritems())
# Out:
# [('California', 0.7423075562540813),
#  ('Northwest', 0.1412218562062946),
#  ('Southwest', 0.11647058753962414)]

# %%
gen_mix.head()
# Out:
#     Subregion FuelCategory   Electricity  Generation_Ratio
# 0  California      BIOMASS  5.102532e+06          0.025792
# 1  California          GAS  8.598807e+07          0.434641
# 2  California   GEOTHERMAL  1.197144e+07          0.060512
# 3  California        HYDRO  3.530088e+07          0.178434
# 4  California      NUCLEAR  1.790108e+07          0.090484

# %%
trading_actual.head()
# Out:
#             AEC          AECI       AVA          AZPS      BANC  BCHA  \
# Source BAA
# AEC         1.0  0.000000e+00  0.000000  0.000000e+00  0.000000   NaN
# AECI        0.0  8.925673e-01  0.000000  0.000000e+00  0.000000   NaN
# AVA         0.0  9.397841e-13  0.669058  2.689387e-05  0.000021   NaN
# AZPS        0.0  2.903284e-08  0.000000  8.308349e-01  0.000000   NaN
# BANC        0.0  1.294045e-17  0.000000  3.703178e-10  0.666805   NaN
#
#                 BPAT  CHPD      CISO          CPLE ...       TEPC      TIDC  \
# Source BAA                                         ...
# AEC         0.000000   0.0  0.000000  4.170836e-06 ...   0.000000  0.000000
# AECI        0.000000   0.0  0.000000  1.178243e-06 ...   0.000000  0.000000
# AVA         0.000063   0.0  0.000019  2.020229e-18 ...   0.000019  0.000007
# AZPS        0.000000   0.0  0.040693  6.241112e-14 ...   0.134546  0.011723
# BANC        0.000000   0.0  0.015923  2.781774e-23 ...   0.000004  0.043916
#
#                 TPWR           TVA          WACM      WALC  WAUE  WAUW  WWA  \
# Source BAA
# AEC         0.000000  4.529113e-05  0.000000e+00  0.000000   NaN   0.0 -0.0
# AECI        0.000000  8.862260e-03  0.000000e+00  0.000000   NaN   0.0 -0.0
# AVA         0.000021  1.519533e-14  1.446163e-07  0.000148   NaN   0.0 -0.0
# AZPS        0.000000  4.694307e-10  4.467646e-03  0.159698   NaN   0.0 -0.0
# BANC        0.000000  2.092335e-19  1.991309e-12  0.000038   NaN   0.0 -0.0
#
#             YAD
# Source BAA
# AEC         0.0
# AECI        0.0
# AVA         0.0
# AZPS        0.0
# BANC        0.0
#
# [5 rows x 74 columns]

# %%
gen_mix.head()
# Out:
#   Subregion FuelCategory   Electricity  Generation_Ratio
# 0       YAD        HYDRO  6.218880e+05          1.000000
# 1      AZPS      BIOMASS  1.714060e+05          0.010781
# 2      AZPS          GAS  3.366437e+06          0.211736
# 3      AZPS        SOLAR  1.836543e+06          0.115512
# 4      AZPS          SUB  1.014088e+07          0.637824

# %%
gen_mix.set_index('Subregion', inplace=True)

# %%
gen_mix['trading_amount'] = trading_actual['AZPS']

# %%
gen_mix.sample(10)
# Out:
#     Subregion FuelCategory   Electricity  Generation_Ratio
# 33       CISO      NUCLEAR  1.790108e+07          0.105415
# 203       PGE          GAS  6.267484e+06          0.519919
# 98        NaN         WIND  3.307429e+06          0.033497
# 204       PGE        HYDRO  2.424309e+06          0.201108
# 75        NaN          BIT  1.137210e+05          0.001150
# 118       NaN          GAS  3.747762e+06          0.254387
# 162      NYIS         WIND  4.135951e+06          0.031574
# 169       NaN        SOLAR  1.363300e+04          0.000736
# 46        DUK        HYDRO  1.674078e+06          0.014620
# 66       ERCO      NUCLEAR  3.858140e+07          0.110585

# %%
def trading_mix_fuels_test(gen_mix, trading_norm):
    # slow but it works
#     assert set(gen_mix.Subregion.unique()) == set(trading_norm.index)
    
#     gen_mix['from_region'] = None
#     gen_mix['region'] = gen_mix['Subregion']
    _gen_mix = gen_mix.dropna().set_index('Subregion')
    print(_gen_mix.head())
    
#     fuels = gen_mix.FuelCategory.unique()
    regions = trading_norm.index
    print(regions[:5])
    
#     m_index = pd.MultiIndex.from_product(iterables=[fuels, regions])
#     base_cols = ['Generation_Ratio', 'trading_gen_ratio']
#     base_df = pd.DataFrame(index=m_index, columns=base_cols)
#     base_df.reset_index(inplace=True)
    
    df_list = []
    for region in regions:
#         input_regions = trading_norm.loc[
#             trading_norm[region] > 0, region
#         ]
        region_df = _gen_mix.copy()
        region_df['trading_amount'] = trading_norm[region]
        region_df['region'] = region
        region_df['trading_gen_ratio'] = (
            region_df['trading_amount']
            * region_df['Generation_Ratio']
        )
        
        if region == 'AZPS':
            print(region_df.sample(10))
        
        df_list.append(region_df)
        
#         for in_region, source_value in input_regions.iteritems():
#             in_fuels = gen_mix.loc[gen_mix.Subregion == in_region, :]
#             in_fuels['from_region'] = in_region
# #             in_fuels['region'] = region
#             in_fuels['trading_gen_ratio'] = (
#                 in_fuels['Generation_Ratio']
#                 * source_value
#             )
            
#             df_list.append(in_fuels)
            
    full_gen_df = pd.concat(df_list)
    full_gen_df['from_region'] = full_gen_df.index
    full_gen_df.dropna(inplace=True)
    full_gen_df.reset_index(drop=True, inplace=True)
    
    keep_cols = [
        'region',
        'from_region',
        'FuelCategory',
        'trading_gen_ratio',
    ]
    full_gen_df = full_gen_df.loc[
        full_gen_df['trading_gen_ratio'] > 0,
        keep_cols
    ]
    
    return full_gen_df

# %%
# %%time
results = trading_mix_fuels_test(gen_mix=gen_mix, trading_norm=trading_actual)
# Out:
#           FuelCategory   Electricity  Generation_Ratio
# Subregion
# YAD              HYDRO  6.218880e+05          1.000000
# AZPS           BIOMASS  1.714060e+05          0.010781
# AZPS               GAS  3.366437e+06          0.211736
# AZPS             SOLAR  1.836543e+06          0.115512
# AZPS               SUB  1.014088e+07          0.637824
# Index(['AEC', 'AECI', 'AVA', 'AZPS', 'BANC'], dtype='object', name='Source BAA')
#           FuelCategory   Electricity  Generation_Ratio  trading_amount region  \
# Subregion
# IPCO              WIND  1.772777e+06      1.266752e-01    1.746624e-04   AZPS
# ERCO              WIND  6.149238e+07      1.762535e-01    0.000000e+00   AZPS
# LDWP             HYDRO  8.982100e+05      7.352442e-02    7.955023e-10   AZPS
# TVA                 RC  8.792838e+06      6.090412e-02    0.000000e+00   AZPS
# IPCO               OIL  1.800000e+01      1.286205e-06    1.746624e-04   AZPS
# SCEG                RC  4.993006e+06      1.947913e-01    0.000000e+00   AZPS
# WALC               OIL  1.200000e+01      7.649836e-07    5.466298e-06   AZPS
# SCEG               BIT  3.566446e+06      1.391371e-01    0.000000e+00   AZPS
# SEPA             SOLAR  4.366600e+04      5.380462e-02    0.000000e+00   AZPS
# CISO        GEOTHERMAL  8.294062e+06      4.884179e-02    1.813372e-08   AZPS
#
#            trading_gen_ratio
# Subregion
# IPCO            2.212540e-05
# ERCO            0.000000e+00
# LDWP            5.848884e-11
# TVA             0.000000e+00
# IPCO            2.246516e-10
# SCEG            0.000000e+00
# WALC            4.181629e-12
# SCEG            0.000000e+00
# SEPA            0.000000e+00
# CISO            8.856833e-10
# CPU times: user 182 ms, sys: 5.73 ms, total: 188 ms
# Wall time: 186 ms

# %%
results.shape
# Out:
# (6520, 4)

# %%
results.loc[results['trading_gen_ratio'] > 0]
# Out:
#       region from_region FuelCategory  trading_gen_ratio
# 138      AEC         AEC      BIOMASS       5.218387e-03
# 139      AEC         AEC          BIT       2.386932e-01
# 140      AEC         AEC          GAS       7.532380e-01
# 141      AEC         AEC        HYDRO       2.850335e-03
# 232     AECI        AZPS      BIOMASS       3.129971e-10
# 233     AECI        AZPS          GAS       6.147306e-09
# 234     AECI        AZPS        SOLAR       3.353632e-09
# 235     AECI        AZPS          SUB       1.851783e-08
# 236     AECI        AZPS         WIND       7.010744e-10
# 237     AECI        DEAA          GAS       1.564605e-13
# 238     AECI        AECI      BIOMASS       5.513396e-04
# 239     AECI        AECI          GAS       1.575957e-01
# 240     AECI        AECI        HYDRO       7.065183e-06
# 241     AECI        AECI          OIL       1.779064e-05
# 242     AECI        AECI           RC       6.754202e-01
# 243     AECI        AECI         WIND       5.897517e-02
# 244     AECI         AVA      BIOMASS       4.641853e-14
# 245     AECI         AVA          GAS       1.948227e-13
# 246     AECI         AVA        HYDRO       6.576709e-13
# 247     AECI         AVA         WIND       4.087189e-14
# 248     AECI        BANC      BIOMASS       1.075948e-19
# 249     AECI        BANC          GAS       8.494167e-18
# 250     AECI        BANC        HYDRO       3.920590e-18
# 251     AECI        BANC        SOLAR       4.180978e-19
# 252     AECI        BPAT      BIOMASS       2.201186e-13
# 253     AECI        BPAT          GAS       2.733084e-12
# 254     AECI        BPAT   GEOTHERMAL       2.719922e-14
# 255     AECI        BPAT        HYDRO       2.724275e-11
# 256     AECI        BPAT      NUCLEAR       2.618342e-12
# 257     AECI        BPAT           RC       1.762594e-12
# ...      ...         ...          ...                ...
# 14236   WALC        PSCO        HYDRO       2.124915e-06
# 14237   WALC        PSCO        SOLAR       8.454628e-06
# 14238   WALC        PSCO          SUB       5.621674e-05
# 14239   WALC        PSCO         WIND       8.545026e-05
# 14240   WALC         PNM      BIOMASS       2.259856e-05
# 14241   WALC         PNM          BIT       3.048385e-03
# 14242   WALC         PNM          GAS       9.150729e-04
# 14243   WALC         PNM   GEOTHERMAL       3.638934e-06
# 14244   WALC         PNM          OIL       1.122868e-09
# 14245   WALC         PNM        SOLAR       9.821825e-05
# 14246   WALC         PNM         WIND       3.973498e-04
# 14247   WALC        CHPD        HYDRO       1.043011e-04
# 14248   WALC        GCPD        HYDRO       1.533015e-04
# 14309   WALC        WALC          GAS       1.359575e-02
# 14310   WALC        WALC        HYDRO       5.400952e-01
# 14311   WALC        WALC          OIL       4.278330e-07
# 14312   WALC        WALC        SOLAR       5.579334e-03
# 14313   WALC        WACM      BIOMASS       4.580027e-05
# 14314   WALC        WACM          BIT       1.875044e-04
# 14315   WALC        WACM          GAS       7.109856e-03
# 14316   WALC        WACM        HYDRO       3.898000e-03
# 14317   WALC        WACM          OIL       5.645440e-06
# 14318   WALC        WACM         OTHF       1.184689e-04
# 14319   WALC        WACM        SOLAR       2.999574e-04
# 14320   WALC        WACM          SUB       7.720117e-02
# 14321   WALC        WACM         WIND       2.387062e-03
# 14419   WAUW         GWA         WIND       1.140591e-02
# 14420   WAUW         WWA         WIND       1.301505e-02
# 14651    WWA         WWA         WIND       1.000000e+00
# 14784    YAD         YAD        HYDRO       1.000000e+00
#
# [6520 rows x 4 columns]

# %%
# %load_ext line_profiler

# %%
# %lprun -f trading_mix_fuels trading_mix_fuels(gen_mix, trading_norm)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 17.2271 s
# File: <ipython-input-26-e4125fd1c779>
# Function: trading_mix_fuels at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def trading_mix_fuels(gen_mix, trading_norm):
#      2                                               # slow but it works
#      3         1       1955.0   1955.0      0.0      assert set(gen_mix.Subregion.unique()) == set(trading_norm.index)
#      4
#      5         1          2.0      2.0      0.0      df_list = []
#      6        14        296.0     21.1      0.0      for region in gen_mix.Subregion.unique():
#      7        13         40.0      3.1      0.0          input_regions = trading_norm.loc[
#      8        13      12139.0    933.8      0.1              trading_norm[region] > 0, region
#      9                                                   ]
#     10
#     11       112       1277.0     11.4      0.0          for in_region, source_value in input_regions.iteritems():
#     12        99     123990.0   1252.4      0.7              in_fuels = gen_mix.loc[gen_mix.Subregion == in_region]
#     13        99    5642279.0  56992.7     32.8              in_fuels['from_region'] = in_region
#     14        99    5640939.0  56979.2     32.7              in_fuels['region'] = region
#     15                                                       in_fuels['trading_gen_ratio'] = (
#     16        99      23181.0    234.2      0.1                  in_fuels['Generation_Ratio']
#     17        99    5670501.0  57277.8     32.9                  * source_value
#     18                                                       )
#     19
#     20        99        446.0      4.5      0.0              df_list.append(in_fuels)
#     21
#     22         1     108357.0 108357.0      0.6      full_gen_df = pd.concat(df_list)
#     23         1        568.0    568.0      0.0      full_gen_df.reset_index(drop=True, inplace=False)
#     24
#     25                                               keep_cols = [
#     26         1          1.0      1.0      0.0          'region',
#     27         1          1.0      1.0      0.0          'from_region',
#     28         1          1.0      1.0      0.0          'FuelCategory',
#     29         1          1.0      1.0      0.0          'trading_gen_ratio',
#     30                                               ]
#     31         1       1094.0   1094.0      0.0      full_gen_df = full_gen_df[keep_cols]
#     32
#     33         1          1.0      1.0      0.0      return full_gen_df

# %%
# %lprun -f trading_mix_fuels trading_mix_fuels(gen_mix, trading_norm)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 12.3054 s
# File: <ipython-input-41-23d09c551f79>
# Function: trading_mix_fuels at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def trading_mix_fuels(gen_mix, trading_norm):
#      2                                               # slow but it works
#      3         1        676.0    676.0      0.0      assert set(gen_mix.Subregion.unique()) == set(trading_norm.index)
#      4
#      5         1        543.0    543.0      0.0      gen_mix['from_region'] = None
#      6         1        514.0    514.0      0.0      gen_mix['region'] = gen_mix['Subregion']
#      7         1        746.0    746.0      0.0      gen_mix['trading_gen_ratio'] = 0
#      8
#      9         1          3.0      3.0      0.0      df_list = []
#     10        14       1086.0     77.6      0.0      for region in gen_mix.Subregion.unique():
#     11        13         42.0      3.2      0.0          input_regions = trading_norm.loc[
#     12        13      14150.0   1088.5      0.1              trading_norm[region] > 0, region
#     13                                                   ]
#     14
#     15       112       1704.0     15.2      0.0          for in_region, source_value in input_regions.iteritems():
#     16        99     159224.0   1608.3      1.3              in_fuels = gen_mix.loc[gen_mix.Subregion == in_region, :]
#     17        99    5978737.0  60391.3     48.6              in_fuels['from_region'] = in_region
#     18                                           #             in_fuels['region'] = region
#     19                                                       in_fuels['trading_gen_ratio'] = (
#     20        99      18846.0    190.4      0.2                  in_fuels['Generation_Ratio']
#     21        99    6040169.0  61011.8     49.1                  * source_value
#     22                                                       )
#     23
#     24        99        429.0      4.3      0.0              df_list.append(in_fuels)
#     25
#     26         1      87222.0  87222.0      0.7      full_gen_df = pd.concat(df_list)
#     27         1        523.0    523.0      0.0      full_gen_df.reset_index(drop=True, inplace=False)
#     28
#     29                                               keep_cols = [
#     30         1          1.0      1.0      0.0          'region',
#     31         1          0.0      0.0      0.0          'from_region',
#     32         1          0.0      0.0      0.0          'FuelCategory',
#     33         1          0.0      0.0      0.0          'trading_gen_ratio',
#     34                                               ]
#     35         1        817.0    817.0      0.0      full_gen_df = full_gen_df[keep_cols]
#     36
#     37         1          0.0      0.0      0.0      return full_gen_df

# %%
# %lprun -f trading_mix_fuels trading_mix_fuels(gen_mix, trading_norm)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 11.7265 s
# File: <ipython-input-34-23d09c551f79>
# Function: trading_mix_fuels at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def trading_mix_fuels(gen_mix, trading_norm):
#      2                                               # slow but it works
#      3         1        618.0    618.0      0.0      assert set(gen_mix.Subregion.unique()) == set(trading_norm.index)
#      4
#      5         1        504.0    504.0      0.0      gen_mix['from_region'] = None
#      6         1        526.0    526.0      0.0      gen_mix['region'] = gen_mix['Subregion']
#      7         1        350.0    350.0      0.0      gen_mix['trading_gen_ratio'] = 0
#      8
#      9         1          2.0      2.0      0.0      df_list = []
#     10        14        578.0     41.3      0.0      for region in gen_mix.Subregion.unique():
#     11        13         40.0      3.1      0.0          input_regions = trading_norm.loc[
#     12        13      11177.0    859.8      0.1              trading_norm[region] > 0, region
#     13                                                   ]
#     14
#     15       112       1187.0     10.6      0.0          for in_region, source_value in input_regions.iteritems():
#     16        99     151551.0   1530.8      1.3              in_fuels = gen_mix.loc[gen_mix.Subregion == in_region, :]
#     17        99    5675523.0  57328.5     48.4              in_fuels['from_region'] = in_region
#     18                                           #             in_fuels['region'] = region
#     19                                                       in_fuels['trading_gen_ratio'] = (
#     20        99      18613.0    188.0      0.2                  in_fuels['Generation_Ratio']
#     21        99    5725537.0  57833.7     48.8                  * source_value
#     22                                                       )
#     23
#     24        99        446.0      4.5      0.0              df_list.append(in_fuels)
#     25
#     26         1     136852.0 136852.0      1.2      full_gen_df = pd.concat(df_list)
#     27         1       1031.0   1031.0      0.0      full_gen_df.reset_index(drop=True, inplace=False)
#     28
#     29                                               keep_cols = [
#     30         1          2.0      2.0      0.0          'region',
#     31         1          1.0      1.0      0.0          'from_region',
#     32         1          1.0      1.0      0.0          'FuelCategory',
#     33         1          1.0      1.0      0.0          'trading_gen_ratio',
#     34                                               ]
#     35         1       1978.0   1978.0      0.0      full_gen_df = full_gen_df[keep_cols]
#     36
#     37         1          2.0      2.0      0.0      return full_gen_df

# %%
df = trading_mix_fuels(gen_mix, trading_norm)

# %%
df.sample(10)
# Out:
#                                    region  \
# 33                           Mid-Atlantic
# 23                                Central
# 67                                Midwest
# 31                              Carolinas
# 6                                 Central
# 55   New York Independent System Operator
# 96                                Central
# 8                              California
# 113                          Mid-Atlantic
# 6                         New England ISO
#
#                                      from_region FuelCategory  \
# 33   Electric Reliability Council of Texas, Inc.          LIG
# 23                                       Central      NUCLEAR
# 67                                       Midwest         OTHF
# 31   Electric Reliability Council of Texas, Inc.          GAS
# 6                                     California          OIL
# 55                                  Mid-Atlantic         OTHF
# 96                                     Northwest         OTHF
# 8                                     California        SOLAR
# 113                                    Southwest        HYDRO
# 6                                     California          OIL
#
#      trading_gen_ratio
# 33        1.924561e-10
# 23        6.994909e-02
# 67        1.526216e-03
# 31        8.435249e-10
# 6         2.409435e-13
# 55        4.546099e-06
# 96        1.722749e-06
# 8         1.031756e-01
# 113       4.773537e-12
# 6         2.443830e-21

# %%
df.to_csv('regional_trading_fuel_results.csv', index=False)

# %%
df.groupby('region')['trading_gen_ratio'].sum()
# Out:
# region
# California                                     1.0
# Carolinas                                      1.0
# Central                                        1.0
# Electric Reliability Council of Texas, Inc.    1.0
# Florida                                        1.0
# Mid-Atlantic                                   1.0
# Midwest                                        1.0
# New England ISO                                1.0
# New York Independent System Operator           1.0
# Northwest                                      1.0
# Southeast                                      1.0
# Southwest                                      1.0
# Tennessee Valley Authority                     1.0
# Name: trading_gen_ratio, dtype: float64

# %%
df.loc[df.region == 'California']
# Out:
#          region from_region FuelCategory  trading_gen_ratio
# 0    California  California      BIOMASS       1.914531e-02
# 1    California  California          GAS       3.226375e-01
# 2    California  California   GEOTHERMAL       4.491826e-02
# 3    California  California        HYDRO       1.324531e-01
# 4    California  California      NUCLEAR       6.716699e-02
# 5    California  California         OFSL       2.496135e-04
# 6    California  California          OIL       1.178448e-04
# 7    California  California         OTHF       2.017203e-03
# 8    California  California        SOLAR       1.031756e-01
# 9    California  California         WIND       5.042608e-02
# 89   California   Northwest      BIOMASS       7.377890e-04
# 90   California   Northwest          BIT       7.667961e-03
# 91   California   Northwest          GAS       2.508432e-02
# 92   California   Northwest   GEOTHERMAL       1.249138e-03
# 93   California   Northwest        HYDRO       5.547241e-02
# 94   California   Northwest      NUCLEAR       3.066391e-03
# 95   California   Northwest          OIL       1.748172e-04
# 96   California   Northwest         OTHF       7.913134e-05
# 97   California   Northwest           RC       2.064208e-03
# 98   California   Northwest        SOLAR       2.237432e-03
# 99   California   Northwest          SUB       3.111809e-02
# 100  California   Northwest         WIND       1.227018e-02
# 109  California   Southwest      BIOMASS       2.125031e-04
# 110  California   Southwest          BIT       2.073465e-02
# 111  California   Southwest          GAS       3.078286e-02
# 112  California   Southwest   GEOTHERMAL       1.090819e-05
# 113  California   Southwest        HYDRO       1.281452e-02
# 114  California   Southwest      NUCLEAR       2.721379e-02
# 115  California   Southwest          OIL       5.048920e-08
# 116  California   Southwest           RC       3.281716e-03
# 117  California   Southwest        SOLAR       3.268285e-03
# 118  California   Southwest          SUB       1.580042e-02
# 119  California   Southwest         WIND       2.350870e-03

# %% [markdown]
# ## Compile flows

# %%
flow_df = get_generation_process_df()
# Out:
# Loading 2017 EIA-923 data from csv file
# Loading 2017 EIA-860 plant data from csv file
# Loading 2015 EIA-923 data from csv file
# Loading 2015 EIA-860 plant data from csv file
# Loading 2016 EIA-923 data from csv file
# Loading 2016 EIA-860 plant data from csv file
# Loading 2017 EIA-923 data from csv file
# Loading 2017 EIA-860 plant data from csv file
# Creating generation process database for Florida ...
# Creating generation process database for Midwest ...
# Creating generation process database for Mid-Atlantic ...
# Creating generation process database for Northwest ...
# Creating generation process database for California ...
# Creating generation process database for New England ISO ...
# Creating generation process database for Carolinas ...
# Creating generation process database for Central ...
# Creating generation process database for New York Independent System Operator ...
# Creating generation process database for Southeast ...
# Creating generation process database for Electric Reliability Council of Texas, Inc. ...
# Creating generation process database for Southwest ...
# Creating generation process database for Tennessee Valley Authority ...
# Generation process database for all complete.

# %%
flow_df.sample(5)
# Out:
#       FuelCategory            FlowName                              FlowUUID  \
# 46795          BIT             Toluene  b43520f0-bcc4-3800-a60e-f8ed389f506a
# 6353       BIOMASS           Beryllium  f0366396-39dc-3c21-9714-ddbb5aef9c4b
# 8108       BIOMASS  Methylene chloride  efc9d45e-81f9-37bd-84e5-13afda41d6be
# 44844           RC        Formaldehyde  3a4fcbc0-6492-3adf-9514-c3a918eb36a1
# 37191          SUB             Toluene  b43520f0-bcc4-3800-a60e-f8ed389f506a
#
#       Compartment  Year Source Unit                   Subregion  \
# 46795         air  2016    NEI   kg  Tennessee Valley Authority
# 6353          air  2016    NEI   kg                Mid-Atlantic
# 8108          air  2016    NEI   kg                  California
# 44844         air  2016    NEI   kg                   Carolinas
# 37191         air  2016    NEI   kg                     Central
#
#       ElementaryFlowPrimeContext  TechnologicalCorrelation  \
# 46795                   emission                       4.0
# 6353                    emission                       4.0
# 8108                    emission                       4.0
# 44844                   emission                       4.0
# 37191                   emission                       4.0
#
#        TemporalCorrelation  DataCollection  Emission_factor  \
# 46795                  1.0             4.0     4.876429e-05
# 6353                   1.0             4.0     1.729877e-07
# 8108                   1.0             4.0     3.725964e-04
# 44844                  1.0             4.0     2.516078e-05
# 37191                  1.0             4.0     1.011570e-04
#
#        Reliability_Score  GeographicalCorrelation        GeomMean  \
# 46795           2.891292                        1   4.4068722e-05
# 6353            1.045520                        1            None
# 8108            2.101672                        1  0.000333769302
# 44844           2.000000                        1   2.4146692e-05
# 37191           3.650650                        1   9.1581319e-05
#
#                GeomSD       Maximum       Minimum
# 46795  1.568305044699  7.921216e-05  7.265105e-06
# 6353             None  9.072709e-07  7.593876e-08
# 8108   1.598617307332  2.116824e-02  1.771885e-06
# 44844  1.332213506015  5.534568e-05  5.324369e-06
# 37191  1.562012428192  9.406947e-04  2.644081e-08

# %%
results = pd.merge(df, flow_df, left_on=['FuelCategory', 'from_region'],
                   right_on=['FuelCategory', 'Subregion'])

# %%
results.sample(10)
# Out:
#                                      region  \
# 21668                          Mid-Atlantic
# 14048                             Northwest
# 27338                               Florida
# 18686  New York Independent System Operator
# 34319  New York Independent System Operator
# 28173                               Florida
# 40925                       New England ISO
# 1189                             California
# 37761                             Southeast
# 40043                          Mid-Atlantic
#
#                                        from_region FuelCategory  \
# 21668                                      Central          LIG
# 14048                                    Southwest           RC
# 27338  Electric Reliability Council of Texas, Inc.          LIG
# 18686                                    Carolinas          OIL
# 34319                                 Mid-Atlantic          OIL
# 28173  Electric Reliability Council of Texas, Inc.      NUCLEAR
# 40925                                      Midwest      NUCLEAR
# 1189                                    California          GAS
# 37761                                      Midwest          BIT
# 40043                                      Midwest          LIG
#
#        trading_gen_ratio                    FlowName  \
# 21668       5.428701e-07            Copper compounds
# 14048       1.368336e-04  Di(2-ethylhexyl) phthalate
# 27338       8.776066e-14          Benzo[ghi]perylene
# 18686       1.453862e-08             Nitrogen oxides
# 34319       7.880067e-05            Dimethyl sulfate
# 28173       1.257547e-13              Acenaphthylene
# 40925       1.237010e-06             Nitrogen oxides
# 1189        3.226375e-01       Dibenz[a,h]anthracene
# 37761       1.290473e-04              Lead compounds
# 40043       1.234882e-04  Di(2-ethylhexyl) phthalate
#
#                                    FlowUUID Compartment  Year Source Unit  \
# 21668  6b14b545-b6d7-31d5-bb10-e4ee0a56cda6         air  2016    TRI   kg
# 14048  ff44086f-099e-32d2-9532-3be566000cc4         air  2016    NEI   kg
# 27338  7e145e90-ed4d-3c84-b19f-a7da241fdb10         air  2016    NEI   kg
# 18686  ff916e13-2e0e-3853-94f8-d7bd94f88f59         air  2016  eGRID   kg
# 34319  a26e77ae-ddb4-3e9d-a442-556fcd0a3f3a         air  2016    NEI   kg
# 28173  316e0c5b-f8a0-3ba5-b33e-0d4724f2e928         air  2016    NEI   kg
# 40925  ff916e13-2e0e-3853-94f8-d7bd94f88f59         air  2016  eGRID   kg
# 1189   d4f8dd30-15a5-3b0b-9661-b2ca97c2f657         air  2016    NEI   kg
# 37761  d13bc6ac-a3b4-3dc8-a265-438200dccef8         air  2016    TRI   kg
# 40043  ff44086f-099e-32d2-9532-3be566000cc4         air  2016    NEI   kg
#
#            ...      TechnologicalCorrelation TemporalCorrelation  \
# 21668      ...                      4.000000                 1.0
# 14048      ...                      4.000000                 1.0
# 27338      ...                      4.000000                 1.0
# 18686      ...                      4.000000                 1.0
# 34319      ...                      4.000000                 1.0
# 28173      ...                      4.000000                 1.0
# 40925      ...                      4.000000                 1.0
# 1189       ...                      4.000000                 1.0
# 37761      ...                      4.001392                 1.0
# 40043      ...                      4.002830                 1.0
#
#        DataCollection  Emission_factor  Reliability_Score  \
# 21668             4.0     1.943348e-05           2.651862
# 14048             4.0     1.848293e-05           2.468690
# 27338             4.0     7.676645e-09           2.000000
# 18686             4.0     1.436637e+01           2.000000
# 34319             4.0     9.125748e-06           2.000000
# 28173             4.0     3.874086e-10           2.000000
# 40925             4.0     4.628335e-04           2.000000
# 1189              4.0     1.045544e-08           1.982946
# 37761             4.0     1.325283e-05           2.184141
# 40043             4.0     1.801307e-05           2.159917
#
#        GeographicalCorrelation         GeomMean          GeomSD       Maximum  \
# 21668                        1    1.8730838e-05  1.311784815142  1.094909e-03
# 14048                        1    1.8050387e-05  1.243121699841  2.037273e-05
# 27338                        1        7.334e-09  1.352567352204  1.113009e-08
# 18686                        1  13.469354291866  1.432027096727  3.217986e+01
# 34319                        1             None            None  1.033281e-05
# 28173                        1             None            None  3.874086e-10
# 40925                        1             None            None  4.773727e-03
# 1189                         1        8.767e-09  1.810222533079  4.332397e-05
# 37761                        1    1.2965404e-05  1.232951563759  1.681944e-04
# 40043                        1    1.7896729e-05  1.120569836496  5.645759e-05
#
#             Minimum
# 21668  4.246685e-06
# 14048  1.357134e-05
# 27338  7.669229e-09
# 18686  8.546093e+00
# 34319  1.033281e-05
# 28173  3.874086e-10
# 40925  2.433419e-04
# 1189   2.319332e-10
# 37761  1.789246e-06
# 40043  7.363693e-06
#
# [10 rows x 22 columns]

# %%
results.to_csv('flows_by_region_trading.gzip', compression='gzip')
